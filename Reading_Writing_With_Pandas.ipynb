# %%
import pandas as pd

# %%
df = pd.read_csv("students - students.csv")

# %%
df.head()
df
# Out:
#                 name  age       sport  Biology_score  Maths_score  \
# 0   Emmanuel Ayomide   27    Football           73.0         58.0
# 1       Ibrahim Musa   24    Football           92.0         56.0
# 2          Sesan Obi   24    Swimming           67.0         95.0
# 3        Kevin Frank   25      Tennis           53.0         85.0
# 4         Emeka Jude   24  Basketball           86.0         80.0
# 5       Caroline Obi   27  Basketball           92.0         71.0
# 6   Franklin Oladele   18    Football           96.0          NaN
# 7           Kola Ola   28    Swimming           82.0         95.0
# 8       Emmanuel Ovi   23      Tennis           79.0         61.0
# 9        Kareem Musa   24    Football           78.0         73.0
# 10    Mustapha Ahmed   24         NaN           88.0         84.0
# 11         Femi Akin   24      Tennis           90.0         97.0
# 12     Tobi Olaniyan   22  Volleyball           51.0         79.0
# ...

# %%
df.to_csv("newdata.csv")

# %%
new_device = pd.read_csv("newdata.csv")

# %%
new_device
# Out:
#     Unnamed: 0              name  age       sport  Biology_score  Maths_score  \
# 0            0  Emmanuel Ayomide   27    Football           73.0         58.0
# 1            1      Ibrahim Musa   24    Football           92.0         56.0
# 2            2         Sesan Obi   24    Swimming           67.0         95.0
# 3            3       Kevin Frank   25      Tennis           53.0         85.0
# 4            4        Emeka Jude   24  Basketball           86.0         80.0
# 5            5      Caroline Obi   27  Basketball           92.0         71.0
# 6            6  Franklin Oladele   18    Football           96.0          NaN
# 7            7          Kola Ola   28    Swimming           82.0         95.0
# 8            8      Emmanuel Ovi   23      Tennis           79.0         61.0
# 9            9       Kareem Musa   24    Football           78.0         73.0
# 10          10    Mustapha Ahmed   24         NaN           88.0         84.0
# ...

# %%
dff = pd.read_excel("mbta2.xlsx")

# %%
dff
# Out:
#     MBTA Avg Weekday Unlinked Passenger Trips (thousands)         Unnamed: 1  \
# 0                                                 NaN                   mode
# 1                                                 1.0       All Modes by Qtr
# 2                                                 2.0                   Boat
# 3                                                 3.0                    Bus
# 4                                                 4.0          Commuter Rail
# 5                                                 5.0             Heavy Rail
# 6                                                 6.0             Light Rail
# 7                                                 7.0           Pct Chg / Yr
# 8                                                 8.0            Private Bus
# 9                                                 9.0                   RIDE
# 10                                               10.0      Trackless Trolley
# ...

# %%
df.to_excel("newdata2.xlsx")

# %%
dff.to_excel("new_kelvin.xlsx")

# %%
url ="https://api.exchangerate-api.com/v4/latest/USD"

# %%
pd.read_json(url)
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XOF  https://www.exchangerate-api.com
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XOF  https://www.exchangerate-api.com/docs/free
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ...
